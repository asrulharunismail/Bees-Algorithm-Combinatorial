# %% [markdown]
# <a href="https://colab.research.google.com/github/asrulharunismail/Bees-Algorithm-Combinatorial/blob/master/AnalSen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
from random import random
#import matplotlib.pyplot as plt

print("Select your Problem -insert a number 1 to 15-")
print(" 1.Eil51"," 2.Berlin52"," 3.St70"," 4.Eil76"," 5.Pr76")
print(" 6.Rat99"," 7.KroA100"," 8.KroB100"," 9.KroC100"," 10.KroD100")
print(" 11.KroE100"," 12.KroA150"," 13.KroB150"," 14.KroA200"," 15.KroB200")
print(" 16.A280"," 17.Pcb442" )
print(" 18.Rat575"," 19.Rat783" )
val = input("Please insert your number 1 to 19: ")
val = int(val)
GS1 = 0
GS1 = int(GS1)
pl1 = 0 #random.randint(1,2)
t=0
GS2 = 0
GS2 = int(GS2)
pl2 = 0
LS = 0
LS = int(LS)
t=0
RunExp = 10
maxIt = 3000
maxIt = int(maxIt)
nScoutBee = input("Please insert your amount of Scout Bee 10 to 40: ")
nScoutBee = int(nScoutBee)
scenario = input("Please insert your scenario (1 to 27): ")
scenario = int(scenario)

class Model:
    def __init__(self,x,y):
        self.x = x
        self.y = y
        self.n = len(x)
    def Dis (self):
        n = self.n
        D = []
        for i in range (n):
            for j in range (n):
                D.append(round(np.sqrt((x[i] - x[j]) ** 2 + (y[i] - y[j]) ** 2)))
        D=np.array(D)
        D=D.reshape(n,n)
        return D
    
# Problem Selection
if val == 1:
    Prob = 'Eil51'
    x = [37, 49, 52, 20, 40, 21, 17, 31, 52, 51, 42, 31, 5, 12, 36, 52, 27, 17, 13, 57, 62, 42, 16, 8, 7, 27, 30, 43, 58, 58, 37, 38, 46, 61, 62, 63, 32, 45, 59, 5, 10, 21, 5, 30, 39, 32, 25, 25, 48, 56, 30]
    y = [52, 49, 64, 26, 30, 47, 63, 62, 33, 21, 41, 32, 25, 42, 16, 41, 23, 33, 13, 58, 42, 57, 57, 52, 38, 68, 48, 67, 48, 27, 69, 46, 10, 33, 63, 69, 22, 35, 15, 6, 17, 10, 64, 15, 10, 39, 32, 55, 28, 37, 40]
    BKS = 426
    Eil51 = Model(x,y)
    D=Eil51.Dis()
    n=Eil51.n
    Probx = Eil51.x
    Proby = Eil51.y
elif val == 2:   
    Prob = 'Berlin52'
    x = [565, 25, 345, 945, 845, 880, 25, 525, 580, 650, 1605, 1220, 1465, 1530, 845, 725, 145, 415, 510, 560, 300, 520, 480, 835, 975, 1215, 1320, 1250, 660, 410, 420, 575, 1150, 700, 685, 685, 770, 795, 720, 760, 475, 95, 875, 700, 555, 830, 1170, 830, 605, 595, 1340, 1740]
    y = [575, 185, 750, 685, 655, 660, 230, 1000, 1175, 1130, 620, 580, 200, 5, 680, 370, 665, 635, 875, 365, 465, 585, 415, 625, 580, 245, 315, 400, 180, 250, 555, 665, 1160, 580, 595, 610, 610, 645, 635, 650, 960, 260, 920, 500, 815, 485, 65, 610, 625, 360, 725, 245]
    BKS = 7542
    Berlin52 = Model(x,y)
    D=Berlin52.Dis()
    n=Berlin52.n
    Probx = Berlin52.x
    Proby = Berlin52.y
elif val == 3:   
    Prob = 'St70'
    x = [64, 80, 69, 72, 48, 58, 81, 79, 30, 42, 7, 29, 78, 64, 95, 57, 40, 68, 92, 62, 28, 76, 67, 93, 6, 87, 30, 77, 78, 55, 82, 73, 20, 27, 95, 67, 48, 75, 8, 20, 54, 63, 44, 52, 12, 25, 58, 5, 90, 41, 25, 37, 56, 10, 98, 16, 89, 48, 81, 29, 17, 5, 79, 9, 17, 74, 10, 48, 83, 84]
    y = [96, 39, 23, 42, 67, 43, 34, 17, 23, 67, 76, 51, 92, 8, 57, 91, 35, 40, 34, 1, 43, 73, 88, 54, 8, 18, 9, 13, 94, 3, 88, 28, 55, 43, 86, 99, 83, 81, 19, 18, 38, 36, 33, 18, 13, 5, 85, 67, 9, 76, 76, 64, 63, 55, 7, 74, 60, 82, 76, 60, 22, 45, 70, 100, 82, 67, 68, 19, 86, 94]
    BKS = 675
    St70 = Model(x,y)
    D=St70.Dis()
    n=St70.n
    Probx = St70.x
    Proby = St70.y
elif val == 4:
    Prob = 'Eil76'
    x = [22, 36, 21, 45, 55, 33, 50, 55, 26, 40, 55, 35, 62, 62, 62, 21, 33, 9, 62, 66, 44, 26, 11, 7, 17, 41, 55, 35, 52, 43, 31, 22, 26, 50, 55, 54, 60, 47, 30, 30, 12, 15, 16, 21, 50, 51, 50, 48, 12, 15, 29, 54, 55, 67, 10, 6, 65, 40, 70, 64, 36, 30, 20, 15, 50, 57, 45, 38, 50, 66, 59, 35, 27, 40, 40, 40]
    y = [22, 26, 45, 35, 20, 34, 50, 45, 59, 66, 65, 51, 35, 57, 24, 36, 44, 56, 48, 14, 13, 13, 28, 43, 64, 46, 34, 16, 26, 26, 76, 53, 29, 40, 50, 10, 15, 66, 60, 50, 17, 14, 19, 48, 30, 42, 15, 21, 38, 56, 39, 38, 57, 41, 70, 25, 27, 60, 64, 4, 6, 20, 30, 5, 70, 72, 42, 33, 4, 8, 5, 60, 24, 20, 37, 40]
    BKS = 538
    Eil76 = Model(x,y)
    D=Eil76.Dis()
    n=Eil76.n
    Probx = Eil76.x
    Proby = Eil76.y
elif val == 5:
    Prob = 'Pr76'
    x = [3600, 3100, 4700, 5400, 5608, 4493, 3600, 3100, 4700, 5400, 5610, 4492, 3600, 3100, 4700, 5400, 6650, 7300, 7300, 6650, 7300, 6650, 5400, 8350, 7850, 9450, 10150, 10358, 9243, 8350, 7850, 9450, 10150, 10360, 9242, 8350, 7850, 9450, 10150, 11400, 12050, 12050, 11400, 12050, 11400, 10150, 13100, 12600, 14200, 14900, 15108, 13993, 13100, 12600, 14200, 14900, 15110, 13992, 13100, 12600, 14200, 14900, 16150, 16800, 16800, 16150, 16800, 16150, 14900, 19800, 19800, 19800, 19800, 200, 200, 200]
2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2100,2100,2100,2200,2200,2200,2200,2300,2300,2300,2400,2400,2400,2500,2500,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2600,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2700,2800,2800,2900,2900,2900,2900,2900,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,3000,150,150,469,469,469,540,540,620,620,750,850,850,850,939,950,910,1050,1150,1170,1220,1350,1350,1350,1450,1550,1550,1550,1650,1690,1710,1710,1750,1790,1720,1790,1720,1829,1829,1829,2060,2050,2170,2110,2120,2150,2290,2220,2280,2390,2320,2450,2620,2750,2760,2850,2850,2850,2930,2950,2950,520,2300,2320,530,2550,750,0]
    y=[400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2600,2700,2800,2900,3000,3100,3200,3300,3400,3500,3600,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2600,2700,2800,2900,3000,3100,3200,3300,3400,3500,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2600,2700,2800,2900,3000,3100,3200,3300,3400,3500,3600,1500,1829,3100,400,300,600,1500,1600,1800,2100,2400,2700,3000,3300,3600,300,600,1030,1500,1800,2100,2400,2600,2700,3000,3300,3600,300,600,1500,1800,2100,2400,2700,3000,3300,3600,300,600,1100,1500,1629,1800,2100,2400,2600,2700,3000,3300,3600,300,600,700,900,1500,1800,2100,2400,2700,3000,3300,3600,300,600,1500,1700,1800,2100,2400,2700,3000,3300,3600,300,600,700,1130,1500,1800,2100,2200,2400,2700,3000,3300,3600,300,600,930,1500,1800,2000,2100,2400,2500,2700,2820,2900,3000,3300,3600,1500,1800,1900,2100,2400,2700,2800,2860,3000,3300,3600,1100,1300,1500,1800,2100,2400,2700,3000,3300,3600,1200,1500,1800,2100,2400,3600,300,600,1230,1500,1800,2100,2400,300,600,3000,3520,300,370,600,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2600,2700,2800,2900,3000,3100,3500,300,600,3200,300,469,600,3200,300,600,3400,300,600,2100,300,800,400,500,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400
    n=Rat783.n
    Probx = Rat783.x
    Proby = Rat783.y

def Cost (tour,D):
    L=0
    for i in range (len(tour)):
        if i< len(tour)-1:
          L += D[tour[i],tour[i+1]]
        else:
          L += D[tour[i],tour[0]]
    return L

def GlobalSearch (GS,n,pl,t):
    if GS == 0:
        IS = np.random.permutation(n)
    elif GS == 1: # Nearest Neighbour
        s = np.random.randint(n)
        D2=D
        D2=np.array(D2)
        n= len(D2)
        IS=[]
        IS.append(s)
        for i in range(1,n):
            s=IS[-1]
            D2[s,:] = np.inf
            temp = list(D2[:,s])
            IS.append(temp.index(min(temp)))
    elif GS ==2: #NSN
        m=pl
        D2=D
        D2=np.array(D2)
        n= len(D2)
        s = np.random.randint(n)
        
        IS=[]
        IS.append(s)
        D2[s,:] = np.inf
        for i in range(1,2):
            #s=IS[-1]
            #D2[s,:] = np.inf
            temp = list(D2[:,s])
            s=temp.index(min(temp))
            IS.append(s)
            D2[s,:] = np.inf
        for i in range(2,n-1):
            #s=IS[-1]
            #D2[s,:] = np.inf
            temp = list(D2[:,s])
            temp2=temp
            #val=np.zeros(m)
            #idx=np.zeros(m)
            val=[]
            idx=[]
            if (n-1)-i >= m:
                mm=m
            else:
                mm= n-i-1
            for j in range(mm):
                val.append(min(temp2))
                idx.append(temp2.index(min(temp2)))
                #temp=np.array(temp)
                temp2[idx[-1]]=np.inf
            
    
            if ((val[-1]-val[0])/val[0]) < t+(random()*(t)):
                Q=[]
                Q.append(x[IS[i-2]])
                Q.append(y[IS[i-2]])
                Q=np.array(Q)
                P=[]
                P.append(x[IS[i-1]])
                P.append(y[IS[i-1]])
                P=np.array(P)
                PQd= np. linalg. norm(P-Q)
                valZ=[]
                for a in range(mm):
                    R=[]
                    R.append(x[idx[a]])
                    R.append(x[idx[a]])
                    R=np.array(R)
                    PQ_PR=sum((Q-P)*(R-P))
                    PRd= np. linalg. norm(P-R)
                    angd=np.arccos(PQ_PR/(PQd*PRd))*180/math.pi
                    valZ.append((1+(2-(angd/90)))*PRd)
                idz =valZ.index(min(valZ))
                s=idx[idz]    
                IS.append(s)
                D2[s,:] = np.inf
           
            else:
                temp = list(D2[:,s])
                s = temp.index(min(temp))
                IS.append(s)
                D2[s,:] = np.inf
        for i in range(n-1,n):
                temp = list(D2[:,s])
                s = temp.index(min(temp))
                IS.append(s)
                D2[s,:] = np.inf
    else:  # Domino sequence operator 
        D2=np.matrix(np.ones((n+1,n+1)) * np.inf)
        for i in range(n):
            for j in range(n):
                D2[i,j]=D[i,j]
        #pl = m[1]      # set the number of players (pl).
        c = np.random.permutation (n)
        c = c+1
        m=math.ceil(n/pl)
        c=np.array(c)
        c.resize(pl,m)
        I = np.random.randint(1,n+1)
        E=[]
        E.append(I)
        T=[]
        T.append(I)
        c[c==I] = 0
        while sum(sum(c)) > 0:
            for i in range(pl):
                FromTo = c[i,:]
                Dis_E = []
                Dis_T = []
                for j in range (m):
                    Dis_E.append(D2[FromTo[j]-1,E[0]-1]) 
                    Dis_T.append(D2[T[-1]-1,FromTo[j]-1])
                minE = min(Dis_E)
                minT = min(Dis_T)
                Id_minE = np.argmin(Dis_E)
                Id_minT = np.argmin(Dis_T)
                if minE <= minT: 
                    E.insert(0,FromTo[Id_minE])
                    c[c==FromTo[Id_minE]] = 0
                else:
                    T.append(FromTo[Id_minT])
                    c[c==FromTo[Id_minT]] = 0
        E = np.array(E)
        E = E[E!=0]
        T = np.array(T)
        T = T[T!=0]
        E=list(E)
        E.pop(-1)
        T=list(T)
        IS = E+T
        IS = (np.array(IS))-1
    IS = list(IS)
    #IS = np.array(IS)
    return IS

def LocalSearch (x,LS):   # Random using Reversion, Swap, Insertion
    if LS == 0:
        m = np.random.randint(1, 4) # The Combination of Swap, Reversion, and Insertion
    else:
        m = LS
    x = list (x)
    n = len(x)
    if m == 1: # SWAP
        for i in range(np.random.choice(range(2), 1)[0]):
            i1, i2 = np.random.choice(range(n), 2, False)
            x[i1], x[i2] = x[i2], x[i1]
    elif m == 2: # REVERSION (2-OPT)
        i = np.random.randint(0,n,2)
        i1 = min(i)
        i2 = max(i)
        x=list(x)
        x[i1:i2:1]= reversed(x[i1:i2:1])
    elif m == 3: # INSERTION
        temp = x[np.random.choice(range(n), 1)[0]]
        x=list(x)
        x.remove(temp)
        x.insert(np.random.choice(range(n-1), 1)[0], temp)
    return x

class Bee:
    def __init__(self,Position,Cost,Counter):
        self.Position = Position
        self.Cost = Cost
        self.Counter = Counter
        
if scenario==1:
    m=0.25
    e=0.20
    nep=1
    nsp=0.25
elif scenario==2:
    m=0.25
    e=0.20
    nep=1
    nsp=0.50
elif scenario==3:
    m=0.25
    e=0.20
    nep=1
    nsp=0.75
elif scenario==4:
    m=0.25
    e=0.40
    nep=1
    nsp=0.25
elif scenario==5:
    m=0.25
    e=0.40
    nep=1
    nsp=0.50
elif scenario==6:
    m=0.25
    e=0.40
    nep=1
    nsp=0.75
elif scenario==7:
    m=0.25
    e=0.60
    nep=1
    nsp=0.25
elif scenario==8:
    m=0.25
    e=0.60
    nep=1
    nsp=0.50
elif scenario==9:
    m=0.25
    e=0.60
    nep=1
    nsp=0.75
elif scenario==10:
    m=0.5
    e=0.20
    nep=1
    nsp=0.25
elif scenario==11:
    m=0.5
    e=0.20
    nep=1
    nsp=0.5
elif scenario==12:
    m=0.5
    e=0.20
    nep=1
    nsp=0.75
elif scenario==13:
    m=0.5
    e=0.40
    nep=1
    nsp=0.25
elif scenario==14:
    m=0.5
    e=0.40
    nep=1
    nsp=0.5
elif scenario==15:
    m=0.5
    e=0.40
    nep=1
    nsp=0.75
elif scenario==16:
    m=0.5
    e=0.60
    nep=1
    nsp=0.25
elif scenario==17:
    m=0.5
    e=0.60
    nep=1
    nsp=0.5
elif scenario==18:
    m=0.5
    e=0.60
    nep=1
    nsp=0.75
elif scenario==19:
    m=0.75
    e=0.20
    nep=1
    nsp=0.25
elif scenario==20:
    m=0.75
    e=0.20
    nep=1
    nsp=0.5
elif scenario==21:
    m=0.75
    e=0.20
    nep=1
    nsp=0.75
elif scenario==22:
    m=0.75
    e=0.40
    nep=1
    nsp=0.25
elif scenario==23:
    m=0.75
    e=0.40
    nep=1
    nsp=0.5
elif scenario==24:
    m=0.75
    e=0.40
    nep=1
    nsp=0.75
elif scenario==25:
    m=0.75
    e=0.60
    nep=1
    nsp=0.25
elif scenario==26:
    m=0.75
    e=0.60
    nep=1
    nsp=0.5
else:
    m=0.75
    e=0.60
    nep=1
    nsp=0.75
    
# Setting Parameters of Bees Algorithm
VarSize = [1, n]  # Decision Variables Matrix Size
nSelectedSite = round(m * nScoutBee)  # m = Number of Selected Sites
nEliteSite = round(e * nSelectedSite)  # e = Number of Selected Elite Sites
nEliteSiteBee = nep * nScoutBee  # nep = Number of Recruited Bees for Elite Sites
nSelectedSiteBee = round( nsp * nEliteSiteBee)  # nsp = Number of Selected Recruited Bees for Selected (m-e) Sites
counter = 0 #Number of evaluation function

#COUNT=[]
#BCOST=[]
FitEval=[]
Bestie=[]
for Exp in range(RunExp):
    # Initialization
    bee=[]
    for i in range(nScoutBee):
        bee.append([])
        tour = GlobalSearch (GS1,n,pl1,t)
        tour = np.array(tour)
        counter += 1
        bee[i]=Bee(tour,Cost(tour,D),counter)
    
    bee.sort(key=lambda bee: bee.Cost, reverse=False)
    
    BestSol = ([],math.inf,math.inf)
    BestSol = bee[0]
    
    BestCost = np.zeros([maxIt,1])
    BestPos = []
    Counter = np.zeros([maxIt*maxIt,1])
    for i in range(maxIt):
        BestPos.append([])
    
    newbee=Bee([],[],[])
    
    # Main Loop
    for it in range(maxIt):
        # Elite Sites
        for i in range(nEliteSite):
    
            bestnewbee=Bee([],math.inf,math.inf)
    
            for j in range(nEliteSiteBee):
                newbee.Position = LocalSearch(bee[i].Position, LS)
                newbee.Cost = Cost(newbee.Position,D)
                counter += 1
                newbee.Counter = counter
                if newbee.Cost < bestnewbee.Cost:
                    bestnewbee.Cost = newbee.Cost
                    bestnewbee.Position = newbee.Position
                    bestnewbee.Counter = counter
    
            if bestnewbee.Cost < bee[i].Cost:
                bee[i].Cost = bestnewbee.Cost
                bee[i].Position = bestnewbee.Position
                bee[i].Counter = bestnewbee.Counter
    
    
        # Selected Non-Elite Sites
        for i in range(nEliteSite,nSelectedSite):
    
            bestnewbee=Bee([],math.inf,math.inf)
    
            for j in range(nSelectedSiteBee):
                newbee.Position = LocalSearch(bee[i].Position, LS)
                newbee.Cost = Cost(newbee.Position,D)
                counter += 1
                newbee.Counter = counter
    
                if newbee.Cost < bestnewbee.Cost:
                    bestnewbee.Cost = newbee.Cost
                    bestnewbee.Position = newbee.Position
                    bestnewbee.Counter = counter
    
            if bestnewbee.Cost < bee[i].Cost:
                bee[i].Cost = bestnewbee.Cost
                bee[i].Position = bestnewbee.Position
                bee[i].Counter = bestnewbee.Counter
    
        # Non - Selected Sites
        for i in range(nSelectedSite,nScoutBee):
            tour = GlobalSearch (GS2,n,pl2,t)
            tour = np.array(tour)
            counter += 1
            bee[i]=Bee(tour,Cost(tour,D),counter)
            
    
        # Sort
        bee.sort(key=lambda bee: bee.Cost, reverse=False)
        # Update
        BestSol.Cost = bee[0].Cost
        BestSol.Position = bee[0].Position
        BestSol.Counter = bee[0].Counter
        # Store Best Cost ever found
        BestCost[it] = BestSol.Cost
        BestPos [it] = BestSol.Position
        Counter [it] = BestSol.Counter
        
        # Display Iteration Information
        print(['Iteration ' + str(it) + ': Best Cost = ' + str(BestCost[it])])
        print(['Iteration ' + str(it) + ': Best Counter = ' + str(Counter [it])])
        #BCOST.append(BestCost[it])
        #COUNT.append(Counter [it])
       ## Drawing the solutions 
        # x and y axis values 
        tour = BestSol.Position
        tour = list(tour)
        tour.append(tour[0])
        tx=[]
        ty=[]
        for i in tour:
            tx.append(Probx[i])
            ty.append(Proby[i])
        x = tx
        y = ty  
        # plotting the points  
        ##plt.plot(x, y, color='green', linestyle='dashed', linewidth = 1, 
        ##marker='o', markerfacecolor='blue', markersize=5) 
        # naming the x axis 
        ##plt.xlabel('x - axis') 
        # naming the y axis 
        ##plt.ylabel('y - axis') 
        # giving a title to my graph 
        ##plt.title("Iteration " + str(it)) 
        # function to show the plot 
        ##plt.show() 
    FitEval.append(Counter [maxIt-1])
    Bestie.append(BestCost[maxIt-1])
    
### Results ##
#import matplotlib.pyplot as plot
#Y = BestCost
#X = []
#for i in range(len(Y)):
#    X.append(i)
## Display grid
#plot.grid(True, which="both")
## Linear X axis, Logarithmic Y axis
#plot.semilogy(X, Y)
#plot.ylim([BKS, BKS*10])
#plot.xlim([0, X.__len__()])
## Provide the title for the semilog plot
#plot.title(Prob)
#plot.xlabel('Iteration')
#plot.ylabel('Best Cost')
#plot.show()
#print("scenario:",scenario,'-nScoutBee:',nScoutBee)
#print(BKS)
#print(BestCost[it])
#print(BestPos [it])
#print("Number of fitness evaluation function:", Counter [it])

print("scenario:",scenario,'-nScoutBee:',nScoutBee)
print("Number of fitness evaluation function:", np.transpose(FitEval))
print(np.transpose(Bestie))
# Out:
# Streaming output truncated to the last 5000 lines.
# ['Iteration 502: Best Cost = [6861.]']
# ['Iteration 502: Best Counter = [20076152.]']
# ['Iteration 503: Best Cost = [6861.]']
# ['Iteration 503: Best Counter = [20076152.]']
# ['Iteration 504: Best Cost = [6849.]']
# ['Iteration 504: Best Counter = [20078349.]']
# ['Iteration 505: Best Cost = [6825.]']
# ['Iteration 505: Best Counter = [20079065.]']
# ['Iteration 506: Best Cost = [6801.]']
# ['Iteration 506: Best Counter = [20079805.]']
# ['Iteration 507: Best Cost = [6801.]']
# ['Iteration 507: Best Counter = [20079805.]']
# ['Iteration 508: Best Cost = [6797.]']
# ['Iteration 508: Best Counter = [20081260.]']
# ['Iteration 509: Best Cost = [6797.]']
# ['Iteration 509: Best Counter = [20081260.]']
# ['Iteration 510: Best Cost = [6797.]']
# ['Iteration 510: Best Counter = [20081260.]']
# ['Iteration 511: Best Cost = [6797.]']
# ['Iteration 511: Best Counter = [20081260.]']
# ['Iteration 512: Best Cost = [6797.]']
# ...
